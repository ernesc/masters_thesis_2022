# %% [markdown]
# <a href="https://colab.research.google.com/github/ernesc/masters_thesis_2022/blob/main/vanilla_LSTM_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data analysis Valve

# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#imports
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional, Activation
import tensorflow as tf
plt.style.use("ggplot")
from ipywidgets.widgets import interact, Layout

# %%
def extract_data(filename, dataframe):
    
    import pandas as pd
    
    df_filename = pd.read_csv(filename,";")

    df_filename_lukket2 = pd.DataFrame()
    df_filename_lukket2 = df_filename_lukket2.append(df_filename[df_filename["Data Source"].str.contains("LUKKET")])
    df_filename_lukket = pd.DataFrame()
    df_filename_lukket = df_filename_lukket.append(df_filename_lukket2[df_filename_lukket2["Value"].str.contains("|".join(["On", "Off"]))])
    df_filename_lukket = df_filename_lukket.rename(columns={"Data Source": "data_source_lukket", 
                                          "Time": "time_lukket", 
                                          "Value": "value_lukket"})
    df_filename_lukket["time_lukket"] = pd.to_datetime(df_filename_lukket["time_lukket"])
    
    
    df_filename_apen1 = pd.DataFrame()
    df_filename_apen1 = df_filename_apen1.append(df_filename[df_filename["Data Source"].str.contains("APEN")])
    df_filename_apen = pd.DataFrame()
    df_filename_apen = df_filename_apen.append(df_filename_apen1[df_filename_apen1["Value"].str.contains("|".join(["On", "Off"]))])
    df_filename_apen = df_filename_apen.rename(columns={"Data Source": "data_source_apen", 
                                      "Time": "time_apen", 
                                      "Value": "value_apen"})
    df_filename_apen["time_apen"] = pd.to_datetime(df_filename_apen["time_apen"])
    
    df_filename_lukket.reset_index(inplace = True)
    df_filename_apen.reset_index(inplace=True)
    df_filename_lukket = df_filename_lukket.drop(columns="index")
    df_filename_apen = df_filename_apen.drop(columns="index")
    
    df_filename_apen['interval'] = pd.to_datetime(df_filename_apen['time_apen'])
    df_filename_lukket['interval'] = pd.to_datetime(df_filename_lukket['time_lukket'])
    
    df_filename_apen.sort_values(by=['interval'])
    df_filename_lukket.sort_values(by=['interval'])
    
    dataframe = pd.merge_asof(df_filename_apen, df_filename_lukket, on='interval', direction="nearest")
    
    
    dataframe["time_diff"] = dataframe["time_apen"] - dataframe["time_lukket"]
    
    dataframe["time_diff_sec"] = dataframe["time_diff"].dt.total_seconds()
    
    dataframe = dataframe.drop(dataframe[dataframe["time_diff_sec"] == 0].index)
    
    return dataframe

# %%
data_2012_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2012.csv", 2012)
data_2013_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2013.csv", 2013)
data_2014_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2014.csv", 2014)
data_2015_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2015.csv", 2015)
data_2016_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2016.csv", 2016)
data_2017_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2017.csv", 2017)
data_2018_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2018.csv", 2018)
data_2019_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2019.csv", 2019)
data_2020_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2020.csv", 2020)
data_2021_1 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg1/2021.csv", 2021)


frames = [data_2012_1, data_2013_1, data_2014_1, data_2015_1, data_2016_1, data_2017_1, data_2018_1, data_2019_1, data_2020_1, data_2021_1]

agg1 = pd.concat(frames)

data_2012_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2012.csv", 2012)
data_2013_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2013.csv", 2013)
data_2014_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2014.csv", 2014)
data_2015_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2015.csv", 2015)
data_2016_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2016.csv", 2016)
data_2017_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2017.csv", 2017)
data_2018_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2018.csv", 2018)
data_2019_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2019.csv", 2019)
data_2020_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2020.csv", 2020)
data_2021_2 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg2/2021.csv", 2021)


frames = [data_2012_2, data_2013_2, data_2014_2, data_2015_2, data_2016_2, data_2017_2, data_2018_2, data_2019_2, data_2020_2, data_2021_2]

agg2 = pd.concat(frames)

data_2012_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2012.csv", 2012)
data_2013_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2013.csv", 2013)
data_2014_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2014.csv", 2014)
data_2015_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2015.csv", 2015)
data_2016_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2016.csv", 2016)
data_2017_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2017.csv", 2017)
data_2018_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2018.csv", 2018)
data_2019_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2019.csv", 2019)
data_2020_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2020.csv", 2020)
data_2021_3 = extract_data("/content/gdrive/My Drive/MASTER_data/nore_1/Agg3/2021.csv", 2021)


frames = [data_2012_3, data_2013_3, data_2014_3, data_2015_3, data_2016_3, data_2017_3, data_2018_3, data_2019_3, data_2020_3, data_2021_3]

agg3 = pd.concat(frames)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only

# %%
agg1_close = agg1[agg1.time_diff_sec < 0]
agg1_open = agg1[agg1.time_diff_sec > 0]
agg1_open_v1 = agg1_open['time_diff_sec']
agg1_close_v1 = agg1_close['time_diff_sec']


agg2_close = agg2[agg2.time_diff_sec < 0]
agg2_open = agg2[agg2.time_diff_sec > 0]
agg2_open_v1 = agg2_open['time_diff_sec']
agg2_close_v1 = agg2_close['time_diff_sec']

agg3_close = agg3[agg3.time_diff_sec < 0]
agg3_open = agg3[agg3.time_diff_sec > 0]
agg3_open_v1 = agg3_open['time_diff_sec']
agg3_close_v1 = agg3_close['time_diff_sec']

# %%
def remove_outliers_v1(data, cutoff):
    data_mean, data_std = np.mean(data), np.std(data)
    cut_off = data_std * cutoff
    lower, upper = data_mean - cut_off, data_mean + cut_off
    outliers = [x for x in data if x < lower or x > upper]
    print('Identified outliers: %d' % len(outliers))
    outliers_removed = [x for x in data if x >= lower and x <= upper]
    print('Non-outlier obs: %d' % len(outliers_removed))
    
    return outliers

# %%
dataset = agg1_open_v1
# validation data is going to be the last 60 cycles
last = 100

# %%
outliers = remove_outliers_v1(dataset, 1)
# Out:
# Identified outliers: 9
# Non-outlier obs: 342

# %%
dataset = dataset[~dataset.isin(outliers)]

# %%
plt.figure(figsize=(12,6))

plt.plot(np.arange(0,len(dataset)),dataset)

# %%
def sliding_window(data, window_size): 
  from numpy import array
  X, y = list(), list()
  for i in range(len(data)):
    # find the end of this pattern
    end_ix = i + window_size
    # check if we are beyond the sequence
    if end_ix > len(data)-1: 
      break
    # gather input and output parts of the pattern
    seq_x, seq_y = data[i:end_ix], data[end_ix] 
    X.append(seq_x)
    y.append(seq_y)
  return array(X), array(y)

# %%
n_steps = 30
# split into samples
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError
cp = ModelCheckpoint('modellstmvan1o2/', save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=100)
X, y = sliding_window(list(dataset)[:len(dataset)-last], n_steps)
X_val, y_val = sliding_window(list(agg3_close_v1)[len(dataset)-last:], n_steps)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X = X.reshape((X.shape[0], X.shape[1], n_features))
# define model
model = Sequential()
model.add(LSTM(150, activation='relu', input_shape=(n_steps, n_features))) 
model.add(Dense(1))
opt = Adam(learning_rate=.0001)
model.compile(optimizer=opt, loss='mse', metrics=[RootMeanSquaredError()])
# fit model


history = model.fit(X, y, epochs=1000, validation_data=(X_val, y_val), verbose=1, callbacks=[cp, early_stopping])
# Out:
# Epoch 1/1000
# 6/7 [========================>.....] - ETA: 0s - loss: 727.7745 - root_mean_squared_error: 26.9773INFO:tensorflow:Assets written to: modellstmvan1o2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fdbb16550d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 7/7 [==============================] - 5s 499ms/step - loss: 813.7799 - root_mean_squared_error: 28.5268 - val_loss: 274132.5625 - val_root_mean_squared_error: 523.5767
# Epoch 2/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 461.4386 - root_mean_squared_error: 21.4811 - val_loss: 278011.8750 - val_root_mean_squared_error: 527.2683
# Epoch 3/1000
# 7/7 [==============================] - ETA: 0s - loss: 167.8866 - root_mean_squared_error: 12.9571INFO:tensorflow:Assets written to: modellstmvan1o2/assets
# INFO:tensorflow:Assets written to: modellstmvan1o2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fdbb16550d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 7/7 [==============================] - 2s 398ms/step - loss: 167.8866 - root_mean_squared_error: 12.9571 - val_loss: 272223.2812 - val_root_mean_squared_error: 521.7502
# Epoch 4/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 174.0890 - root_mean_squared_error: 13.1943 - val_loss: 277447.9688 - val_root_mean_squared_error: 526.7333
# Epoch 5/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 209.6702 - root_mean_squared_error: 14.4800 - val_loss: 283913.4375 - val_root_mean_squared_error: 532.8353
# Epoch 6/1000
# 7/7 [==============================] - 0s 54ms/step - loss: 233.7370 - root_mean_squared_error: 15.2885 - val_loss: 289948.7188 - val_root_mean_squared_error: 538.4689
# Epoch 7/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 114.6585 - root_mean_squared_error: 10.7079 - val_loss: 273987.9688 - val_root_mean_squared_error: 523.4386
# Epoch 8/1000
# 7/7 [==============================] - 0s 54ms/step - loss: 50.8158 - root_mean_squared_error: 7.1285 - val_loss: 272541.9688 - val_root_mean_squared_error: 522.0555
# Epoch 9/1000
# 7/7 [==============================] - ETA: 0s - loss: 34.1203 - root_mean_squared_error: 5.8413INFO:tensorflow:Assets written to: modellstmvan1o2/assets
# INFO:tensorflow:Assets written to: modellstmvan1o2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fdbb16550d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 7/7 [==============================] - 3s 437ms/step - loss: 34.1203 - root_mean_squared_error: 5.8413 - val_loss: 271015.0938 - val_root_mean_squared_error: 520.5911
# Epoch 10/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 47.0904 - root_mean_squared_error: 6.8622 - val_loss: 273018.0312 - val_root_mean_squared_error: 522.5113
# Epoch 11/1000
# 7/7 [==============================] - ETA: 0s - loss: 20.6952 - root_mean_squared_error: 4.5492INFO:tensorflow:Assets written to: modellstmvan1o2/assets
# INFO:tensorflow:Assets written to: modellstmvan1o2/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fdbb16550d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 7/7 [==============================] - 2s 396ms/step - loss: 20.6952 - root_mean_squared_error: 4.5492 - val_loss: 269701.6250 - val_root_mean_squared_error: 519.3281
# Epoch 12/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 8.4356 - root_mean_squared_error: 2.9044 - val_loss: 277966.5312 - val_root_mean_squared_error: 527.2253
# Epoch 13/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 37.2933 - root_mean_squared_error: 6.1068 - val_loss: 283694.4375 - val_root_mean_squared_error: 532.6298
# Epoch 14/1000
# 7/7 [==============================] - 0s 60ms/step - loss: 18.8393 - root_mean_squared_error: 4.3404 - val_loss: 291848.2188 - val_root_mean_squared_error: 540.2298
# Epoch 15/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 114.0126 - root_mean_squared_error: 10.6777 - val_loss: 289169.1250 - val_root_mean_squared_error: 537.7445
# Epoch 16/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 446.1089 - root_mean_squared_error: 21.1213 - val_loss: 279947.8750 - val_root_mean_squared_error: 529.1010
# Epoch 17/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 146.0807 - root_mean_squared_error: 12.0864 - val_loss: 279611.6562 - val_root_mean_squared_error: 528.7832
# Epoch 18/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 86.1947 - root_mean_squared_error: 9.2841 - val_loss: 279682.0000 - val_root_mean_squared_error: 528.8497
# Epoch 19/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 402.5457 - root_mean_squared_error: 20.0635 - val_loss: 292165.0312 - val_root_mean_squared_error: 540.5229
# Epoch 20/1000
# 7/7 [==============================] - 0s 62ms/step - loss: 298.6255 - root_mean_squared_error: 17.2808 - val_loss: 303269.8125 - val_root_mean_squared_error: 550.6994
# Epoch 21/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 131.3360 - root_mean_squared_error: 11.4602 - val_loss: 293407.3750 - val_root_mean_squared_error: 541.6709
# Epoch 22/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 95.8078 - root_mean_squared_error: 9.7881 - val_loss: 295128.6875 - val_root_mean_squared_error: 543.2575
# Epoch 23/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 317.6544 - root_mean_squared_error: 17.8229 - val_loss: 289103.9688 - val_root_mean_squared_error: 537.6839
# Epoch 24/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 384.3109 - root_mean_squared_error: 19.6038 - val_loss: 295105.6250 - val_root_mean_squared_error: 543.2363
# Epoch 25/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 112.1562 - root_mean_squared_error: 10.5904 - val_loss: 287114.2188 - val_root_mean_squared_error: 535.8304
# Epoch 26/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 92.2912 - root_mean_squared_error: 9.6068 - val_loss: 287998.5625 - val_root_mean_squared_error: 536.6550
# Epoch 27/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 26.5076 - root_mean_squared_error: 5.1486 - val_loss: 298522.1250 - val_root_mean_squared_error: 546.3718
# Epoch 28/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 11.0038 - root_mean_squared_error: 3.3172 - val_loss: 285308.0312 - val_root_mean_squared_error: 534.1423
# Epoch 29/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 22.1159 - root_mean_squared_error: 4.7028 - val_loss: 287276.4062 - val_root_mean_squared_error: 535.9818
# Epoch 30/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 17.2071 - root_mean_squared_error: 4.1481 - val_loss: 288893.1875 - val_root_mean_squared_error: 537.4879
# Epoch 31/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 11.5977 - root_mean_squared_error: 3.4055 - val_loss: 299004.0000 - val_root_mean_squared_error: 546.8126
# Epoch 32/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 7.4427 - root_mean_squared_error: 2.7281 - val_loss: 297593.9375 - val_root_mean_squared_error: 545.5217
# Epoch 33/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 6.0125 - root_mean_squared_error: 2.4520 - val_loss: 282874.5000 - val_root_mean_squared_error: 531.8595
# Epoch 34/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 5.0133 - root_mean_squared_error: 2.2390 - val_loss: 273262.0625 - val_root_mean_squared_error: 522.7448
# Epoch 35/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 4.5688 - root_mean_squared_error: 2.1375 - val_loss: 294629.2500 - val_root_mean_squared_error: 542.7976
# Epoch 36/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 4.0811 - root_mean_squared_error: 2.0202 - val_loss: 296301.1250 - val_root_mean_squared_error: 544.3355
# Epoch 37/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.7978 - root_mean_squared_error: 1.9488 - val_loss: 281841.7500 - val_root_mean_squared_error: 530.8877
# Epoch 38/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.8084 - root_mean_squared_error: 1.9515 - val_loss: 277984.4688 - val_root_mean_squared_error: 527.2423
# Epoch 39/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.7214 - root_mean_squared_error: 1.9291 - val_loss: 291667.0312 - val_root_mean_squared_error: 540.0621
# Epoch 40/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.6859 - root_mean_squared_error: 1.9199 - val_loss: 286248.1875 - val_root_mean_squared_error: 535.0217
# Epoch 41/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.6324 - root_mean_squared_error: 1.9059 - val_loss: 289176.2812 - val_root_mean_squared_error: 537.7512
# Epoch 42/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.5974 - root_mean_squared_error: 1.8967 - val_loss: 303315.8438 - val_root_mean_squared_error: 550.7411
# Epoch 43/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 3.5704 - root_mean_squared_error: 1.8896 - val_loss: 287120.4062 - val_root_mean_squared_error: 535.8362
# Epoch 44/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.5465 - root_mean_squared_error: 1.8832 - val_loss: 296967.6875 - val_root_mean_squared_error: 544.9474
# Epoch 45/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 3.5297 - root_mean_squared_error: 1.8787 - val_loss: 286420.9688 - val_root_mean_squared_error: 535.1831
# Epoch 46/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.5146 - root_mean_squared_error: 1.8747 - val_loss: 295372.6250 - val_root_mean_squared_error: 543.4819
# Epoch 47/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.4957 - root_mean_squared_error: 1.8697 - val_loss: 289207.8750 - val_root_mean_squared_error: 537.7805
# Epoch 48/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.4865 - root_mean_squared_error: 1.8672 - val_loss: 302057.3438 - val_root_mean_squared_error: 549.5974
# Epoch 49/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.4673 - root_mean_squared_error: 1.8621 - val_loss: 293968.6562 - val_root_mean_squared_error: 542.1888
# Epoch 50/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.4504 - root_mean_squared_error: 1.8575 - val_loss: 272365.9688 - val_root_mean_squared_error: 521.8869
# Epoch 51/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.4397 - root_mean_squared_error: 1.8546 - val_loss: 282845.3438 - val_root_mean_squared_error: 531.8321
# Epoch 52/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.4281 - root_mean_squared_error: 1.8515 - val_loss: 293747.0938 - val_root_mean_squared_error: 541.9844
# Epoch 53/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.4289 - root_mean_squared_error: 1.8517 - val_loss: 290888.5000 - val_root_mean_squared_error: 539.3408
# Epoch 54/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.3965 - root_mean_squared_error: 1.8430 - val_loss: 298662.1562 - val_root_mean_squared_error: 546.4999
# Epoch 55/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.3899 - root_mean_squared_error: 1.8412 - val_loss: 298073.3438 - val_root_mean_squared_error: 545.9609
# Epoch 56/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.3721 - root_mean_squared_error: 1.8363 - val_loss: 310948.8125 - val_root_mean_squared_error: 557.6279
# Epoch 57/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.3906 - root_mean_squared_error: 1.8414 - val_loss: 299018.6875 - val_root_mean_squared_error: 546.8260
# Epoch 58/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.3748 - root_mean_squared_error: 1.8371 - val_loss: 274478.0312 - val_root_mean_squared_error: 523.9065
# Epoch 59/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.3807 - root_mean_squared_error: 1.8387 - val_loss: 279595.0000 - val_root_mean_squared_error: 528.7675
# Epoch 60/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.3658 - root_mean_squared_error: 1.8346 - val_loss: 280394.4062 - val_root_mean_squared_error: 529.5228
# Epoch 61/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.3362 - root_mean_squared_error: 1.8265 - val_loss: 277136.0625 - val_root_mean_squared_error: 526.4371
# Epoch 62/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.3205 - root_mean_squared_error: 1.8222 - val_loss: 290176.5625 - val_root_mean_squared_error: 538.6804
# Epoch 63/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.3132 - root_mean_squared_error: 1.8202 - val_loss: 288351.3750 - val_root_mean_squared_error: 536.9836
# Epoch 64/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.3150 - root_mean_squared_error: 1.8207 - val_loss: 288977.8438 - val_root_mean_squared_error: 537.5666
# Epoch 65/1000
# 7/7 [==============================] - 0s 60ms/step - loss: 3.2854 - root_mean_squared_error: 1.8126 - val_loss: 288630.6562 - val_root_mean_squared_error: 537.2436
# Epoch 66/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.2950 - root_mean_squared_error: 1.8152 - val_loss: 289900.6250 - val_root_mean_squared_error: 538.4242
# Epoch 67/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.2825 - root_mean_squared_error: 1.8118 - val_loss: 293486.0938 - val_root_mean_squared_error: 541.7436
# Epoch 68/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.2637 - root_mean_squared_error: 1.8066 - val_loss: 293118.5625 - val_root_mean_squared_error: 541.4042
# Epoch 69/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.2749 - root_mean_squared_error: 1.8097 - val_loss: 294214.4375 - val_root_mean_squared_error: 542.4153
# Epoch 70/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.2596 - root_mean_squared_error: 1.8054 - val_loss: 296905.5000 - val_root_mean_squared_error: 544.8904
# Epoch 71/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.2488 - root_mean_squared_error: 1.8024 - val_loss: 295706.8750 - val_root_mean_squared_error: 543.7894
# Epoch 72/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.2502 - root_mean_squared_error: 1.8028 - val_loss: 284085.0625 - val_root_mean_squared_error: 532.9963
# Epoch 73/1000
# 7/7 [==============================] - 1s 93ms/step - loss: 3.2342 - root_mean_squared_error: 1.7984 - val_loss: 283804.2500 - val_root_mean_squared_error: 532.7328
# Epoch 74/1000
# 7/7 [==============================] - 1s 121ms/step - loss: 3.2180 - root_mean_squared_error: 1.7939 - val_loss: 283779.3125 - val_root_mean_squared_error: 532.7094
# Epoch 75/1000
# 7/7 [==============================] - 0s 64ms/step - loss: 3.2216 - root_mean_squared_error: 1.7949 - val_loss: 281949.7812 - val_root_mean_squared_error: 530.9894
# Epoch 76/1000
# 7/7 [==============================] - 1s 140ms/step - loss: 3.2137 - root_mean_squared_error: 1.7927 - val_loss: 283421.0000 - val_root_mean_squared_error: 532.3730
# Epoch 77/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.2079 - root_mean_squared_error: 1.7910 - val_loss: 288921.7188 - val_root_mean_squared_error: 537.5144
# Epoch 78/1000
# 7/7 [==============================] - 1s 148ms/step - loss: 3.2088 - root_mean_squared_error: 1.7913 - val_loss: 286527.2500 - val_root_mean_squared_error: 535.2824
# Epoch 79/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.2338 - root_mean_squared_error: 1.7983 - val_loss: 291792.5938 - val_root_mean_squared_error: 540.1783
# Epoch 80/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 3.2076 - root_mean_squared_error: 1.7910 - val_loss: 288360.8125 - val_root_mean_squared_error: 536.9924
# Epoch 81/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.2261 - root_mean_squared_error: 1.7961 - val_loss: 289040.3750 - val_root_mean_squared_error: 537.6248
# Epoch 82/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.1779 - root_mean_squared_error: 1.7827 - val_loss: 287093.5625 - val_root_mean_squared_error: 535.8111
# Epoch 83/1000
# 7/7 [==============================] - 0s 60ms/step - loss: 3.2036 - root_mean_squared_error: 1.7899 - val_loss: 288781.7188 - val_root_mean_squared_error: 537.3842
# Epoch 84/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.1707 - root_mean_squared_error: 1.7806 - val_loss: 287767.4688 - val_root_mean_squared_error: 536.4396
# Epoch 85/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.1585 - root_mean_squared_error: 1.7772 - val_loss: 286575.4375 - val_root_mean_squared_error: 535.3274
# Epoch 86/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.2280 - root_mean_squared_error: 1.7967 - val_loss: 287032.8125 - val_root_mean_squared_error: 535.7545
# Epoch 87/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.1211 - root_mean_squared_error: 1.7667 - val_loss: 287381.1250 - val_root_mean_squared_error: 536.0794
# Epoch 88/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.1733 - root_mean_squared_error: 1.7814 - val_loss: 287788.3750 - val_root_mean_squared_error: 536.4591
# Epoch 89/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.1396 - root_mean_squared_error: 1.7719 - val_loss: 285654.6562 - val_root_mean_squared_error: 534.4667
# Epoch 90/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.1205 - root_mean_squared_error: 1.7665 - val_loss: 284660.5000 - val_root_mean_squared_error: 533.5358
# Epoch 91/1000
# 7/7 [==============================] - 0s 60ms/step - loss: 3.1198 - root_mean_squared_error: 1.7663 - val_loss: 283219.5938 - val_root_mean_squared_error: 532.1838
# Epoch 92/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.1027 - root_mean_squared_error: 1.7615 - val_loss: 283597.6562 - val_root_mean_squared_error: 532.5389
# Epoch 93/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.1092 - root_mean_squared_error: 1.7633 - val_loss: 283427.7812 - val_root_mean_squared_error: 532.3793
# Epoch 94/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.1165 - root_mean_squared_error: 1.7654 - val_loss: 285121.0312 - val_root_mean_squared_error: 533.9673
# Epoch 95/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.1442 - root_mean_squared_error: 1.7732 - val_loss: 284994.3438 - val_root_mean_squared_error: 533.8486
# Epoch 96/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.0891 - root_mean_squared_error: 1.7576 - val_loss: 286932.5000 - val_root_mean_squared_error: 535.6608
# Epoch 97/1000
# 7/7 [==============================] - 0s 61ms/step - loss: 3.1269 - root_mean_squared_error: 1.7683 - val_loss: 287717.6875 - val_root_mean_squared_error: 536.3932
# Epoch 98/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.0904 - root_mean_squared_error: 1.7580 - val_loss: 282598.4375 - val_root_mean_squared_error: 531.5999
# Epoch 99/1000
# 7/7 [==============================] - 0s 60ms/step - loss: 3.0966 - root_mean_squared_error: 1.7597 - val_loss: 291053.3438 - val_root_mean_squared_error: 539.4936
# Epoch 100/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.0794 - root_mean_squared_error: 1.7548 - val_loss: 286089.6562 - val_root_mean_squared_error: 534.8735
# Epoch 101/1000
# 7/7 [==============================] - 0s 61ms/step - loss: 3.0710 - root_mean_squared_error: 1.7524 - val_loss: 290225.5625 - val_root_mean_squared_error: 538.7259
# Epoch 102/1000
# 7/7 [==============================] - 0s 61ms/step - loss: 3.0825 - root_mean_squared_error: 1.7557 - val_loss: 292939.7812 - val_root_mean_squared_error: 541.2391
# Epoch 103/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.0727 - root_mean_squared_error: 1.7529 - val_loss: 287492.1250 - val_root_mean_squared_error: 536.1829
# Epoch 104/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.0508 - root_mean_squared_error: 1.7467 - val_loss: 290330.6562 - val_root_mean_squared_error: 538.8234
# Epoch 105/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.0840 - root_mean_squared_error: 1.7561 - val_loss: 288572.1250 - val_root_mean_squared_error: 537.1891
# Epoch 106/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.0448 - root_mean_squared_error: 1.7449 - val_loss: 288658.0312 - val_root_mean_squared_error: 537.2690
# Epoch 107/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.0592 - root_mean_squared_error: 1.7490 - val_loss: 274489.4062 - val_root_mean_squared_error: 523.9174
# Epoch 108/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 3.0351 - root_mean_squared_error: 1.7422 - val_loss: 282620.4375 - val_root_mean_squared_error: 531.6206
# Epoch 109/1000
# 7/7 [==============================] - 0s 59ms/step - loss: 3.0424 - root_mean_squared_error: 1.7443 - val_loss: 274707.5938 - val_root_mean_squared_error: 524.1255
# Epoch 110/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 3.0369 - root_mean_squared_error: 1.7427 - val_loss: 279969.2812 - val_root_mean_squared_error: 529.1212
# Epoch 111/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 3.0282 - root_mean_squared_error: 1.7402 - val_loss: 284572.7188 - val_root_mean_squared_error: 533.4536

# %%
plt.figure(figsize = (14,7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# demonstrate prediction for next cycles
from tensorflow.keras.models import load_model
model100 = load_model('modellstmvan1o2/')

x_input = np.array(list(dataset)[-n_steps-1:])
temp_input=list(x_input)
lst_output=[]
i=0
cycles = last
while(i<cycles):
    
    if(len(temp_input)>3):
        x_input=np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, n_features))
        yhat = model100.predict(x_input, verbose=0)
        temp_input.append(yhat[0][0])
        temp_input=temp_input[1:]
        lst_output.append(yhat[0][0])
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps, n_features))
        yhat = model100.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.append(yhat[0][0])
        lst_output.append(yhat[0][0])
        i=i+1

# %%
new_cycle=np.arange(0,len(dataset)-last)
cycle_pred=np.arange(len(dataset)-last,len(dataset)-last+cycles)
plt.figure(figsize=(14,7))
plt.plot(new_cycle,list(dataset)[:len(dataset)-last], 
         label='Training Data')
plt.plot(np.arange(len(dataset)-last,len(dataset)), 
         list(dataset)[len(dataset)-last:], label='Validation Data', ls='-')
plt.plot(cycle_pred,lst_output, c='green', label='Prediction', ls='--')

plt.xlabel('Number of cycles', fontsize=15)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.ylabel('Time-lag (seconds)', fontsize=15)
plt.legend(fontsize=15)
plt.savefig('/content/gdrive/My Drive/MASTER_data/vanillaLSTM_agg1_open.png')

# %%
from tensorflow.keras.metrics import mean_squared_error

print(f'RMSE {np.sqrt(mean_squared_error(list(dataset)[len(dataset)-last:], lst_output))}')
print(f'STD {np.std(np.array(list(dataset)[len(dataset)-last:]) - np.array(lst_output))}')
print(f'Correlation {np.corrcoef(np.array((np.array(list(dataset)[len(dataset)-last:]), np.array(lst_output))))[0, 1]}')
print(f'SAD {np.sum(np.abs(np.array((np.array(list(dataset)[len(dataset)-last:]) - np.array(lst_output)))))}')
print(f'SSD {np.sum(np.square(np.array((np.array(list(dataset)[len(dataset)-last:]) - np.array(lst_output)))))}')
# Out:
# RMSE 2.1821858882904053
# STD 2.013436002759053
# Correlation 0.1607524388953787
# SAD 161.08618440258766
# SSD 476.19356065301383

# %%
plt.figure(figsize=(14,7))
plt.hist(np.array((np.array(list(dataset)[len(dataset)-last:]))), 5, label='Validation data')
plt.hist(lst_output, 5, label='Prediction')
plt.ylabel('Amount of values in a bin', fontsize=15)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.xlabel('Time-lag (seconds)', fontsize=15)
plt.legend(fontsize=15)

# %%
import scipy.stats as st
a = list(dataset)[len(dataset)-last:]
b = lst_output
plt.figure(figsize=(14,7))
plt.hist(a, density=True, bins=10, label="Validation data")
plt.hist(b, density=True, bins=10, label="Prediction")
mn, mx = plt.xlim()
plt.xlim(mn, mx)
kde_xs = np.linspace(mn, mx, 300)
kde = st.gaussian_kde(a)
plt.plot(kde_xs, kde.pdf(kde_xs), label="PDF Validation")
kdeb = st.gaussian_kde(b)
plt.plot(kde_xs, kdeb.pdf(kde_xs), label="PDF Prediction")
plt.legend(loc="upper right", fontsize=15)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.ylabel("Probability", fontsize=15)
plt.xlabel("Data", fontsize=15)
plt.title("Histogram", fontsize=17);
